# %% [markdown]
# ## PLANS AND TODO:
#
# Get basis using NMF on regular season data for players who played in the playoffs. removing players who took fewer than 50 shots in reg and 2 in playoffs
#
# use this basis to characterize each player during regular season and playoffs to compare their shooting styles during each interval of time
#
# Posssibly use KNN to determine which players play similarly, group them
#
# Use this somehow

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import myFunctions as mf
import importlib

# %%
importlib.reload(mf)
# Out:
# <module 'myFunctions' from '/home/jovyan/Pstat134/Final Project/BasketballPlayoffs/myFunctions.py'>

# %%
plyrs = pickle.load(open( "allplayers.p", "rb" ))
plyrsreg = pickle.load(open("allplayersregular.p","rb"))
PIDS = [i for i in plyrs.keys()]

# %%
print(plyrs[PIDS[0]].iloc[0].PLAYER_NAME)
# Out:
# David West

# %% [markdown]
# ## Regular Season vs Playoffs

# %%
# Create DataFrames will all shot data from regular season and playoffs
shots =  []
for i in PIDS:
    if(len(plyrsreg[i].index) < 50 or len(plyrs[i].index) < 2):
        continue # Skip players who did not take over 100 shots during regular season
    shots.append(plyrsreg[i])
    tmp = plyrs[i]
    tmp['PLAYER_ID'] *= -1 #to separate playoffs from regular. Easy to convert back to
    shots.append(tmp)
allshots = pd.concat(shots,ignore_index = True)

# %%
# Create smoothed bins of shots for all players
xedges = np.linspace(start=-300, stop=300, num=151)
yedges = np.linspace(start=-48, stop=372, num=106)
bin_edges = (xedges, yedges)

nx = xedges.size - 1
ny = yedges.size - 1
player_dict = {}
FPIDS = []
all_smooth = []
for i in enumerate(allshots.groupby('PLAYER_ID')):
    tmp, xedges, yedges = mf.bin_shots(i[1][1], bin_edges=(xedges, yedges), density=True, sigma=2) #i[1][1] is df
    ## vectorize and store into list
    all_smooth += [tmp.reshape(-1)]
    FPIDS.append(i[1][1].PLAYER_ID.iloc[0])
    player_dict[i[1][1].PLAYER_ID.iloc[0]] = i[1][1].PLAYER_NAME.iloc[0]
X = np.vstack(all_smooth).T
p,n = X.shape
print(p,n) # n is number of players, p is shot regions
# Out:
# 15750 34

# %%
W,H = mf.non_negative_marix_decomp(5,X)

# %%
fig, ax = plt.subplots(1, 5, figsize=(20,60))
## Write a for loop
for i in range(5):
    mf.plot_vectorized_shotchart(W[:,i],xedges,yedges,ax = ax[i])
    ax[i].set_title('Shot Basis %i' % (i+1))

# %%
comp = []
for i in range(len(FPIDS)):
    comp.append([H[:,i]])
comp = pd.DataFrame(index = FPIDS, data = comp)
for i in FPIDS:
    if(i < 0):
        continue
    print("Player Name:",player_dict[i])
    print("Shots Taken Regular Season:",len(plyrsreg[i].index))
    print("Shots Taken Playoffs:",len(plyrs[i].index))
    print(comp.loc[i][0])
    print(comp.loc[-i][0])
# Out:
# Player Name: Jason Terry
# Shots Taken Regular Season: 154
# Shots Taken Playoffs: 5
# [0.24120093 0.01043947 0.0547543  0.20909792 0.01654814]
# [0.         0.         0.         1.69748822 0.        ]
# Player Name: Manu Ginobili
# Shots Taken Regular Season: 463
# Shots Taken Playoffs: 37
# [0.59620624 0.05458047 0.01235235 0.11181944 0.01751539]
# [0.32739153 0.08514443 0.         0.11575914 0.05327816]
# Player Name: Joe Johnson
# Shots Taken Regular Season: 360
# Shots Taken Playoffs: 17
# [0.16218057 0.01381797 0.01307322 0.0826576  0.        ]
# [0.25227117 0.00763603 0.         0.1135571  0.01731021]
# Player Name: Carmelo Anthony
# Shots Taken Regular Season: 1168
# Shots Taken Playoffs: 72
# [0.34121194 0.00329202 0.00786441 0.10764257 0.        ]
# [0.36305379 0.04250111 0.01788564 0.12608615 0.0009246 ]
# Player Name: David West
# Shots Taken Regular Season: 378
# Shots Taken Playoffs: 45
# [0.64403156 0.0595734  0.         0.         0.082241  ]
# [0.7614649  0.         0.         0.         0.18638163]
# Player Name: Marcin Gortat
# Shots Taken Regular Season: 560
# Shots Taken Playoffs: 43
# [0.88583544 0.05881738 0.         0.         0.06652151]
# [1.05764726 0.00906411 0.         0.         0.02916264]
# Player Name: Nick Young
# Shots Taken Regular Season: 488
# Shots Taken Playoffs: 53
# [0.21251034 0.         0.02485947 0.17985631 0.00857831]
# [0.07733087 0.02026267 0.04510272 0.26498273 0.        ]
# Player Name: Aaron Brooks
# Shots Taken Regular Season: 69
# Shots Taken Playoffs: 3
# [0.45655926 0.01933983 0.01911976 0.10894606 0.03471656]
# [0.         0.         0.         0.         0.99729341]
# Player Name: Luc Mbah a Moute
# Shots Taken Regular Season: 345
# Shots Taken Playoffs: 36
# [0.7952833  0.0590096  0.00574456 0.1084183  0.09087797]
# [0.83513527 0.06303438 0.00250889 0.16080341 0.        ]
# Player Name: Brandon Jennings
# Shots Taken Regular Season: 72
# Shots Taken Playoffs: 2
# [0.2413713  0.07053257 0.02317649 0.22905963 0.        ]
# [0.         0.         1.12463743 0.         0.        ]
# Player Name: Trevor Booker
# Shots Taken Regular Season: 343
# Shots Taken Playoffs: 10
# [0.92292444 0.0824536  0.00339992 0.         0.00856608]
# [1.72187943 0.0046721  0.         0.         0.        ]
# Player Name: Shabazz Muhammad
# Shots Taken Regular Season: 188
# Shots Taken Playoffs: 20
# [0.7965539  0.07943541 0.00256866 0.01622598 0.07961458]
# [0.73512923 0.04666349 0.         0.01643088 0.05694289]
# Player Name: Shane Larkin
# Shots Taken Regular Season: 219
# Shots Taken Playoffs: 35
# [0.49628259 0.06180963 0.01306417 0.15367009 0.00310069]
# [0.99713634 0.0423866  0.         0.07565593 0.03179941]
# Player Name: Alex Abrines
# Shots Taken Regular Season: 291
# Shots Taken Playoffs: 20
# [0.3684851  0.00874907 0.02279312 0.27595971 0.        ]
# [0.17357521 0.017835   0.00664989 0.41697389 0.104818  ]
# Player Name: Josh Huestis
# Shots Taken Regular Season: 182
# Shots Taken Playoffs: 2
# [0.73089186 0.02304982 0.00566547 0.10635935 0.        ]
# [0.         1.12645771 0.         0.         0.        ]
# Player Name: Tarik Black
# Shots Taken Regular Season: 127
# Shots Taken Playoffs: 4
# [1.42074805e+00 5.88378056e-02 1.31297510e-04 0.00000000e+00
#  1.89405967e-01]
# [0.2581334  0.36122233 0.         0.         0.73414274]
# Player Name: Dejounte Murray
# Shots Taken Regular Season: 609
# Shots Taken Playoffs: 31
# [0.95316806 0.04484599 0.         0.         0.0052555 ]
# [0.61348298 0.02100144 0.         0.02733054 0.        ]

# %% [markdown]
# ## Playstyles between different quarters

# %%
# Create DataFrames will all shot data from regular season
shots =  []
tmp = []
flag = True
for i in PIDS:
    for j in range(4):
        if(len(plyrsreg[i].PERIOD.value_counts()) < 4  or plyrsreg[i].PERIOD.value_counts().iloc[j] < 2):
            flag = False
    if flag:
        temp = plyrsreg[i].copy()
        temp.drop(temp.index[temp.PERIOD>4],inplace = True) # To remove data that goes into overtime
        shots.append(temp)
    flag = True
periodShots = pd.concat(shots,ignore_index = True)

# %%
print(temp.PERIOD)
temp.drop(temp.index[temp.PERIOD>4],inplace = True)
print(temp.PERIOD)
# Out:
# 0      1
# 1      1
# 2      4
# 3      4
# 4      4
# 5      1
# 6      1
# 7      2
# 8      2
# 9      3
# 10     4
# 11     4
# 12     4
# 13     1
# 14     1
# 15     1
# 16     4
# 17     4
# 18     1
# 19     1
# 20     1
# 21     4
# 22     4
# 23     4
# 24     4
# 25     4
# 26     4
# 27     1
# 28     4
# 29     4
#       ..
# 260    4
# 261    4
# 262    4
# 263    2
# 264    2
# 265    2
# 266    4
# 267    4
# 268    2
# 269    4
# 270    4
# 271    4
# 272    4
# 274    2
# 275    3
# 276    4
# 277    1
# 278    2
# 279    2
# 280    3
# 281    4
# 282    1
# 283    1
# 284    2
# 285    3
# 286    4
# 287    4
# 288    4
# 289    4
# 290    1
# Name: PERIOD, Length: 288, dtype: int64
# 0      1
# 1      1
# 2      4
# 3      4
# 4      4
# 5      1
# 6      1
# 7      2
# 8      2
# 9      3
# 10     4
# 11     4
# 12     4
# 13     1
# 14     1
# 15     1
# 16     4
# 17     4
# 18     1
# 19     1
# 20     1
# 21     4
# 22     4
# 23     4
# 24     4
# 25     4
# 26     4
# 27     1
# 28     4
# 29     4
#       ..
# 260    4
# 261    4
# 262    4
# 263    2
# 264    2
# 265    2
# 266    4
# 267    4
# 268    2
# 269    4
# 270    4
# 271    4
# 272    4
# 274    2
# 275    3
# 276    4
# 277    1
# 278    2
# 279    2
# 280    3
# 281    4
# 282    1
# 283    1
# 284    2
# 285    3
# 286    4
# 287    4
# 288    4
# 289    4
# 290    1
# Name: PERIOD, Length: 288, dtype: int64

# %%
player_dict = {}
FPIDS = []
FPIDSloop = []
period = []
numShots = {}
all_smooth = []
for i in enumerate(periodShots.groupby(['PLAYER_ID','PERIOD'])):
    temp = i[1][1]
    #temp.drop([temp.PERIOD > 4])
    tmp, xedges, yedges = mf.bin_shots(temp, bin_edges=(xedges, yedges), density=True, sigma=2) #i[1][1] is df
    ## vectorize and store into list
    all_smooth += [tmp.reshape(-1)]
    if(temp.PLAYER_ID.iloc[0] not in FPIDS):
        FPIDS.append(temp.PLAYER_ID.iloc[0])
        player_dict[temp.PLAYER_ID.iloc[0]] = temp.PLAYER_NAME.iloc[0]
        numShots[temp.PLAYER_ID.iloc[0]] = []
    FPIDSloop.append(temp.PLAYER_ID.iloc[0])
    period.append(temp.PERIOD.iloc[0])
    numShots[temp.PLAYER_ID.iloc[0]].append(len(i[1][1]))
X = np.vstack(all_smooth).T
p,n = X.shape
print(p,n) # n is number of players, p is shot regions
# Out:
# 15750 400

# %%
W,H = mf.non_negative_marix_decomp(5,X)

# %%
fig, ax = plt.subplots(1, 5, figsize=(20,60))
## Write a for loop
for i in range(5):
    mf.plot_vectorized_shotchart(W[:,i],xedges,yedges,ax = ax[i])
    ax[i].set_title('Shot Basis %i' % (i+1))

# %%
comp = []
comprounded = []
for i in range(len(FPIDSloop)):
    comprounded.append([H[:,i].round(3)])
    comp.append([H[:,i]])
comp = pd.DataFrame(index = [FPIDSloop,period], data = comp)
comprounded = pd.DataFrame(index = [FPIDSloop,period], data = comprounded)
for i in FPIDS:
    print("Player Name:",player_dict[i])
    output = "Period 1: {} Period 2: {} Period 3: {} Period 4: {}"
    print("Shots Taken", output.format(numShots[i][0],numShots[i][1],numShots[i][2],numShots[i][3]))
    print(comprounded.loc[i])
# Out:
# Player Name: Jason Terry
# Shots Taken Period 1: 25 Period 2: 52 Period 3: 26 Period 4: 50
#                                      0
# 1    [0.104, 1.308, 0.0, 0.058, 0.052]
# 2  [0.167, 1.073, 0.021, 0.045, 0.015]
# 3      [0.215, 0.763, 0.0, 0.0, 0.011]
# 4       [0.033, 1.04, 0.007, 0.0, 0.0]
# Player Name: Manu Ginobili
# Shots Taken Period 1: 112 Period 2: 125 Period 3: 129 Period 4: 95
#                                      0
# 1  [0.115, 0.289, 0.274, 0.101, 0.093]
# 2  [0.228, 0.433, 0.153, 0.118, 0.047]
# 3  [0.187, 0.418, 0.165, 0.054, 0.075]
# 4  [0.119, 0.419, 0.188, 0.181, 0.067]
# Player Name: Joe Johnson
# Shots Taken Period 1: 73 Period 2: 99 Period 3: 99 Period 4: 86
#                                    0
# 1    [0.089, 0.485, 0.044, 0.0, 0.0]
# 2  [0.053, 0.518, 0.057, 0.0, 0.038]
# 3  [0.056, 0.645, 0.015, 0.0, 0.004]
# 4    [0.076, 0.545, 0.037, 0.0, 0.0]
# Player Name: Zach Randolph
# Shots Taken Period 1: 266 Period 2: 137 Period 3: 270 Period 4: 83
#                                      0
# 1  [0.163, 0.231, 0.151, 0.027, 0.047]
# 2   [0.249, 0.217, 0.154, 0.04, 0.042]
# 3   [0.26, 0.218, 0.135, 0.069, 0.028]
# 4    [0.295, 0.193, 0.173, 0.037, 0.1]
# Player Name: Carmelo Anthony
# Shots Taken Period 1: 366 Period 2: 271 Period 3: 333 Period 4: 190
#                                     0
# 1  [0.091, 0.434, 0.033, 0.09, 0.063]
# 2   [0.097, 0.41, 0.052, 0.07, 0.033]
# 3  [0.026, 0.56, 0.027, 0.054, 0.021]
# 4   [0.034, 0.51, 0.054, 0.119, 0.03]
# Player Name: David West
# Shots Taken Period 1: 3 Period 2: 201 Period 3: 3 Period 4: 171
#                                      0
# 1        [0.807, 0.0, 0.0, 0.012, 0.0]
# 2  [0.321, 0.068, 0.097, 0.087, 0.074]
# 3        [0.0, 0.0, 0.565, 0.545, 0.0]
# 4    [0.374, 0.024, 0.188, 0.191, 0.0]
# Player Name: Emeka Okafor
# Shots Taken Period 1: 39 Period 2: 7 Period 3: 35 Period 4: 14
#                                   0
# 1  [0.169, 0.0, 0.111, 0.442, 0.08]
# 2     [0.0, 0.0, 0.164, 0.582, 0.0]
# 3  [0.189, 0.0, 0.175, 0.33, 0.088]
# 4    [0.347, 0.0, 0.086, 0.47, 0.0]
# Player Name: Al Jefferson
# Shots Taken Period 1: 43 Period 2: 66 Period 3: 41 Period 4: 58
#                                      0
# 1     [0.151, 0.03, 0.233, 0.113, 0.0]
# 2  [0.197, 0.034, 0.148, 0.117, 0.068]
# 3   [0.34, 0.017, 0.082, 0.147, 0.036]
# 4   [0.181, 0.04, 0.096, 0.233, 0.037]
# Player Name: Jameer Nelson
# Shots Taken Period 1: 42 Period 2: 72 Period 3: 49 Period 4: 78
#                                      0
# 1       [0.0, 0.833, 0.0, 0.05, 0.035]
# 2  [0.028, 0.552, 0.003, 0.068, 0.124]
# 3   [0.23, 0.395, 0.035, 0.092, 0.114]
# 4    [0.002, 0.535, 0.111, 0.0, 0.143]
# Player Name: Tony Allen
# Shots Taken Period 1: 16 Period 2: 32 Period 3: 12 Period 4: 31
#                                      0
# 1     [0.323, 0.112, 0.0, 0.351, 0.37]
# 2  [0.281, 0.103, 0.168, 0.327, 0.269]
# 3  [0.562, 0.256, 0.166, 0.303, 0.276]
# 4    [0.497, 0.0, 0.519, 0.335, 0.134]
# Player Name: Damien Wilkins
# Shots Taken Period 1: 3 Period 2: 9 Period 3: 4 Period 4: 23
#                                      0
# 1       [0.359, 0.0, 0.12, 0.0, 0.438]
# 2      [0.0, 1.098, 0.193, 0.051, 0.0]
# 3      [0.244, 0.31, 0.0, 0.193, 0.15]
# 4  [0.246, 0.446, 0.009, 0.074, 0.087]
# Player Name: Jarrett Jack
# Shots Taken Period 1: 132 Period 2: 107 Period 3: 107 Period 4: 86
#                                      0
# 1   [0.131, 0.319, 0.04, 0.047, 0.039]
# 2  [0.118, 0.298, 0.035, 0.012, 0.073]
# 3  [0.199, 0.239, 0.043, 0.014, 0.074]
# 4  [0.198, 0.212, 0.113, 0.018, 0.054]
# Player Name: Marcin Gortat
# Shots Taken Period 1: 231 Period 2: 78 Period 3: 194 Period 4: 51
#                                    0
# 1   [0.319, 0.0, 0.135, 0.15, 0.084]
# 2   [0.355, 0.0, 0.18, 0.168, 0.097]
# 3  [0.432, 0.0, 0.159, 0.244, 0.086]
# 4   [0.46, 0.0, 0.097, 0.244, 0.119]
# Player Name: Brandan Wright
# Shots Taken Period 1: 28 Period 2: 31 Period 3: 22 Period 4: 21
#                                    0
# 1   [0.444, 0.0, 0.03, 0.583, 0.122]
# 2  [0.746, 0.0, 0.134, 0.427, 0.034]
# 3     [0.566, 0.0, 0.531, 0.26, 0.0]
# 4    [0.465, 0.0, 0.139, 0.7, 0.003]
# Player Name: Nick Young
# Shots Taken Period 1: 94 Period 2: 111 Period 3: 93 Period 4: 190
#                                      0
# 1  [0.049, 0.705, 0.046, 0.032, 0.027]
# 2  [0.076, 0.754, 0.029, 0.015, 0.027]
# 3  [0.053, 1.013, 0.004, 0.001, 0.019]
# 4  [0.085, 0.677, 0.002, 0.017, 0.057]
# Player Name: Jason Smith
# Shots Taken Period 1: 7 Period 2: 30 Period 3: 9 Period 4: 69
#                                     0
# 1       [0.29, 0.676, 0.0, 0.0, 0.05]
# 2  [0.221, 0.506, 0.032, 0.13, 0.093]
# 3   [0.295, 0.075, 0.066, 0.129, 0.0]
# 4  [0.178, 0.301, 0.075, 0.065, 0.12]
# Player Name: Aaron Brooks
# Shots Taken Period 1: 4 Period 2: 15 Period 3: 11 Period 4: 39
#                                    0
# 1    [0.0, 0.287, 0.437, 0.122, 0.0]
# 2  [0.052, 0.533, 0.271, 0.004, 0.0]
# 3  [0.584, 0.204, 0.0, 0.174, 0.113]
# 4  [0.185, 0.5, 0.009, 0.025, 0.132]
# Player Name: Arron Afflalo
# Shots Taken Period 1: 21 Period 2: 66 Period 3: 13 Period 4: 62
#                                    0
# 1   [0.208, 0.529, 0.0, 0.04, 0.091]
# 2   [0.13, 0.741, 0.024, 0.0, 0.066]
# 3  [0.167, 0.605, 0.0, 0.031, 0.192]
# 4    [0.138, 0.747, 0.0, 0.0, 0.011]
# Player Name: Ramon Sessions
# Shots Taken Period 1: 19 Period 2: 26 Period 3: 23 Period 4: 49
#                                      0
# 1  [0.408, 0.349, 0.021, 0.114, 0.091]
# 2   [0.399, 0.228, 0.09, 0.218, 0.197]
# 3     [0.18, 0.263, 0.116, 0.257, 0.2]
# 4  [0.461, 0.185, 0.054, 0.084, 0.098]
# Player Name: Andre Ingram
# Shots Taken Period 1: 5 Period 2: 4 Period 3: 4 Period 4: 4
#                                  0
# 1      [0.0, 0.961, 0.0, 0.0, 0.0]
# 2    [0.0, 0.798, 0.002, 0.0, 0.0]
# 3    [0.0, 0.628, 0.007, 0.0, 0.0]
# 4  [0.142, 0.546, 0.049, 0.0, 0.0]
# Player Name: Michael Beasley
# Shots Taken Period 1: 167 Period 2: 211 Period 3: 188 Period 4: 231
#                                      0
# 1   [0.27, 0.144, 0.137, 0.098, 0.059]
# 2  [0.301, 0.091, 0.129, 0.164, 0.087]
# 3  [0.279, 0.099, 0.192, 0.117, 0.101]
# 4   [0.275, 0.095, 0.153, 0.18, 0.083]
# Player Name: Marreese Speights
# Shots Taken Period 1: 50 Period 2: 103 Period 3: 62 Period 4: 134
#                                      0
# 1      [0.0, 0.794, 0.051, 0.0, 0.003]
# 2  [0.127, 0.509, 0.024, 0.061, 0.044]
# 3  [0.049, 0.622, 0.012, 0.029, 0.028]
# 4   [0.113, 0.655, 0.02, 0.015, 0.023]
# Player Name: Darrell Arthur
# Shots Taken Period 1: 13 Period 2: 10 Period 3: 5 Period 4: 19
#                                      0
# 1      [0.197, 0.338, 0.0, 0.0, 0.043]
# 2  [0.173, 0.371, 0.126, 0.148, 0.168]
# 3        [0.0, 0.513, 0.005, 0.0, 0.0]
# 4    [0.149, 0.471, 0.086, 0.012, 0.0]
# Player Name: Mario Chalmers
# Shots Taken Period 1: 111 Period 2: 107 Period 3: 108 Period 4: 117
#                                      0
# 1   [0.233, 0.46, 0.033, 0.053, 0.166]
# 2  [0.227, 0.374, 0.073, 0.116, 0.186]
# 3   [0.192, 0.417, 0.156, 0.07, 0.135]
# 4   [0.168, 0.471, 0.097, 0.08, 0.104]
# Player Name: Omer Asik
# Shots Taken Period 1: 6 Period 2: 5 Period 3: 4 Period 4: 7
#                                    0
# 1       [0.94, 0.0, 0.0, 0.0, 0.291]
# 2  [0.137, 0.0, 0.623, 0.418, 0.472]
# 3      [1.321, 0.0, 0.0, 0.0, 0.689]
# 4    [0.399, 0.0, 0.274, 0.459, 0.3]
# Player Name: Luc Mbah a Moute
# Shots Taken Period 1: 104 Period 2: 82 Period 3: 77 Period 4: 82
#                                      0
# 1   [0.263, 0.759, 0.12, 0.183, 0.125]
# 2  [0.383, 0.444, 0.307, 0.155, 0.071]
# 3   [0.429, 0.566, 0.144, 0.15, 0.093]
# 4   [0.34, 0.731, 0.111, 0.116, 0.143]
# Player Name: Bobby Brown
# Shots Taken Period 1: 3 Period 2: 6 Period 3: 7 Period 4: 42
#                                     0
# 1       [0.0, 0.558, 0.003, 0.0, 0.0]
# 2   [0.403, 0.249, 0.274, 0.143, 0.0]
# 3       [0.0, 0.645, 0.0, 0.006, 0.0]
# 4  [0.077, 0.552, 0.056, 0.08, 0.044]
# Player Name: Tyreke Evans
# Shots Taken Period 1: 167 Period 2: 217 Period 3: 180 Period 4: 241
#                                      0
# 1  [0.408, 0.254, 0.084, 0.198, 0.178]
# 2  [0.402, 0.307, 0.104, 0.211, 0.158]
# 3  [0.438, 0.335, 0.103, 0.169, 0.122]
# 4  [0.427, 0.295, 0.145, 0.193, 0.091]
# Player Name: Brandon Jennings
# Shots Taken Period 1: 10 Period 2: 21 Period 3: 17 Period 4: 24
#                                     0
# 1       [0.228, 0.597, 0.0, 0.0, 0.0]
# 2   [0.162, 0.578, 0.161, 0.037, 0.0]
# 3  [0.148, 0.619, 0.173, 0.01, 0.035]
# 4     [0.0, 0.578, 0.169, 0.0, 0.002]
# Player Name: Luke Babbitt
# Shots Taken Period 1: 54 Period 2: 54 Period 3: 49 Period 4: 58
#                                     0
# 1    [0.013, 0.88, 0.016, 0.018, 0.0]
# 2   [0.023, 0.811, 0.029, 0.0, 0.048]
# 3        [0.07, 0.918, 0.0, 0.0, 0.0]
# 4  [0.06, 0.734, 0.055, 0.013, 0.017]
# Player Name: Trevor Booker
# Shots Taken Period 1: 101 Period 2: 94 Period 3: 65 Period 4: 83
#                                      0
# 1  [0.351, 0.058, 0.214, 0.108, 0.122]
# 2  [0.231, 0.056, 0.254, 0.198, 0.093]
# 3   [0.271, 0.105, 0.231, 0.117, 0.09]
# 4   [0.291, 0.051, 0.17, 0.314, 0.065]
# Player Name: Timofey Mozgov
# Shots Taken Period 1: 15 Period 2: 30 Period 3: 24 Period 4: 24
#                                      0
# 1    [0.066, 0.228, 0.148, 0.584, 0.0]
# 2    [0.446, 0.189, 0.164, 0.524, 0.0]
# 3   [0.426, 0.248, 0.28, 0.184, 0.077]
# 4  [0.475, 0.235, 0.093, 0.201, 0.265]
# Player Name: MarShon Brooks
# Shots Taken Period 1: 18 Period 2: 31 Period 3: 17 Period 4: 36
#                                      0
# 1        [0.0, 0.3, 0.078, 0.117, 0.0]
# 2  [0.108, 0.202, 0.228, 0.204, 0.201]
# 3      [0.195, 0.378, 0.165, 0.0, 0.0]
# 4   [0.123, 0.503, 0.078, 0.02, 0.072]
# Player Name: Kyle Singler
# Shots Taken Period 1: 3 Period 2: 2 Period 3: 2 Period 4: 14
#                                    0
# 1    [0.756, 0.258, 0.061, 0.0, 0.0]
# 2        [0.0, 0.0, 1.243, 0.0, 0.0]
# 3    [0.298, 0.0, 0.0, 0.233, 0.676]
# 4  [0.173, 0.331, 0.0, 0.087, 0.257]
# Player Name: DeAndre Liggins
# Shots Taken Period 1: 19 Period 2: 28 Period 3: 20 Period 4: 37
#                                      0
# 1  [0.299, 0.704, 0.011, 0.161, 0.033]
# 2  [0.105, 0.877, 0.011, 0.082, 0.172]
# 3     [0.17, 0.836, 0.0, 0.054, 0.207]
# 4  [0.013, 0.445, 0.034, 0.094, 0.122]
# Player Name: Dwight Buycks
# Shots Taken Period 1: 33 Period 2: 50 Period 3: 39 Period 4: 76
#                                      0
# 1  [0.331, 0.222, 0.067, 0.072, 0.092]
# 2  [0.115, 0.107, 0.347, 0.056, 0.265]
# 3     [0.157, 0.23, 0.018, 0.0, 0.236]
# 4    [0.25, 0.225, 0.19, 0.035, 0.112]
# Player Name: Marquis Teague
# Shots Taken Period 1: 6 Period 2: 3 Period 3: 4 Period 4: 3
#                                  0
# 1  [0.015, 0.315, 0.002, 0.0, 0.0]
# 2      [0.0, 0.0, 0.0, 0.0, 1.005]
# 3    [0.0, 0.728, 0.0, 0.0, 0.376]
# 4   [0.0, 0.0, 0.69, 0.053, 0.549]
# Player Name: Quincy Acy
# Shots Taken Period 1: 93 Period 2: 86 Period 3: 93 Period 4: 89
#                                      0
# 1     [0.05, 1.085, 0.0, 0.005, 0.025]
# 2  [0.099, 0.929, 0.067, 0.063, 0.019]
# 3  [0.124, 0.887, 0.048, 0.059, 0.027]
# 4  [0.118, 0.891, 0.046, 0.027, 0.056]
# Player Name: Mirza Teletovic
# Shots Taken Period 1: 16 Period 2: 16 Period 3: 10 Period 4: 15
#                                     0
# 1       [0.0, 0.987, 0.004, 0.0, 0.0]
# 2  [0.079, 0.689, 0.01, 0.115, 0.124]
# 3        [0.0, 1.21, 0.001, 0.0, 0.0]
# 4       [0.0, 0.477, 0.058, 0.0, 0.0]
# Player Name: Willie Reed
# Shots Taken Period 1: 28 Period 2: 35 Period 3: 30 Period 4: 28
#                                    0
# 1   [0.344, 0.0, 0.082, 0.28, 0.106]
# 2  [0.676, 0.0, 0.199, 0.232, 0.056]
# 3   [0.254, 0.0, 0.391, 0.435, 0.09]
# 4  [0.728, 0.0, 0.135, 0.246, 0.055]
# Player Name: Andre Roberson
# Shots Taken Period 1: 52 Period 2: 38 Period 3: 49 Period 4: 21
#                                      0
# 1    [0.29, 0.052, 0.26, 0.609, 0.103]
# 2     [0.253, 0.184, 0.1, 0.522, 0.21]
# 3  [0.185, 0.207, 0.201, 0.574, 0.233]
# 4  [0.513, 0.299, 0.295, 0.263, 0.091]
# Player Name: Ben McLemore
# Shots Taken Period 1: 96 Period 2: 89 Period 3: 85 Period 4: 103
#                                      0
# 1   [0.17, 0.456, 0.184, 0.076, 0.066]
# 2  [0.121, 0.532, 0.103, 0.153, 0.069]
# 3  [0.185, 0.465, 0.168, 0.136, 0.016]
# 4   [0.159, 0.43, 0.113, 0.158, 0.106]
# Player Name: Brandon Paul
# Shots Taken Period 1: 30 Period 2: 18 Period 3: 26 Period 4: 53
#                                      0
# 1  [0.059, 0.507, 0.268, 0.195, 0.053]
# 2  [0.007, 0.674, 0.065, 0.215, 0.123]
# 3   [0.334, 0.569, 0.08, 0.077, 0.073]
# 4  [0.306, 0.295, 0.208, 0.165, 0.101]
# Player Name: Shabazz Muhammad
# Shots Taken Period 1: 13 Period 2: 84 Period 3: 30 Period 4: 61
#                                      0
# 1    [0.789, 0.125, 0.289, 0.065, 0.0]
# 2  [0.423, 0.114, 0.138, 0.165, 0.051]
# 3  [0.356, 0.234, 0.065, 0.132, 0.084]
# 4   [0.278, 0.171, 0.167, 0.27, 0.007]
# Player Name: Shane Larkin
# Shots Taken Period 1: 21 Period 2: 78 Period 3: 27 Period 4: 93
#                                      0
# 1  [0.055, 0.132, 0.228, 0.099, 0.233]
# 2  [0.101, 0.518, 0.066, 0.084, 0.088]
# 3   [0.217, 0.348, 0.277, 0.109, 0.06]
# 4   [0.201, 0.428, 0.183, 0.06, 0.003]
# Player Name: Lucas Nogueira
# Shots Taken Period 1: 15 Period 2: 16 Period 3: 16 Period 4: 33
#                                      0
# 1    [0.419, 0.0, 0.199, 0.466, 0.311]
# 2  [0.504, 0.225, 0.109, 0.211, 0.489]
# 3   [0.234, 0.063, 0.301, 0.484, 0.16]
# 4   [0.085, 0.154, 0.11, 0.624, 0.207]
# Player Name: Alex Abrines
# Shots Taken Period 1: 69 Period 2: 91 Period 3: 38 Period 4: 90
#                                      0
# 1  [0.057, 0.842, 0.025, 0.076, 0.053]
# 2   [0.065, 0.873, 0.05, 0.095, 0.041]
# 3  [0.128, 0.772, 0.068, 0.045, 0.022]
# 4  [0.086, 0.926, 0.037, 0.071, 0.042]
# Player Name: Joffrey Lauvergne
# Shots Taken Period 1: 47 Period 2: 34 Period 3: 42 Period 4: 67
#                                      0
# 1    [0.375, 0.0, 0.163, 0.289, 0.111]
# 2  [0.425, 0.127, 0.274, 0.209, 0.069]
# 3    [0.179, 0.0, 0.244, 0.585, 0.055]
# 4    [0.432, 0.0, 0.126, 0.265, 0.172]
# Player Name: Josh Magette
# Shots Taken Period 1: 9 Period 2: 11 Period 3: 13 Period 4: 13
#                                  0
# 1  [0.006, 0.554, 0.013, 0.0, 0.0]
# 2  [0.0, 0.559, 0.007, 0.0, 0.011]
# 3   [0.077, 0.53, 0.118, 0.0, 0.0]
# 4   [0.05, 0.367, 0.001, 0.0, 0.0]
# Player Name: Tyler Ennis
# Shots Taken Period 1: 40 Period 2: 56 Period 3: 43 Period 4: 77
#                                      0
# 1   [0.459, 0.134, 0.22, 0.096, 0.058]
# 2    [0.375, 0.27, 0.07, 0.059, 0.124]
# 3  [0.594, 0.108, 0.335, 0.094, 0.061]
# 4  [0.534, 0.201, 0.069, 0.005, 0.139]
# Player Name: Sean Kilpatrick
# Shots Taken Period 1: 36 Period 2: 81 Period 3: 47 Period 4: 130
#                                      0
# 1  [0.245, 0.561, 0.126, 0.036, 0.049]
# 2  [0.171, 0.573, 0.009, 0.042, 0.104]
# 3     [0.165, 0.565, 0.0, 0.141, 0.08]
# 4  [0.267, 0.544, 0.182, 0.048, 0.042]
# Player Name: Johnny O'Bryant III
# Shots Taken Period 1: 31 Period 2: 58 Period 3: 8 Period 4: 74
#                                      0
# 1      [0.258, 0.275, 0.038, 0.0, 0.0]
# 2  [0.202, 0.379, 0.066, 0.033, 0.043]
# 3      [0.327, 0.081, 0.0, 0.206, 0.0]
# 4  [0.191, 0.176, 0.191, 0.153, 0.034]
# Player Name: JaKarr Sampson
# Shots Taken Period 1: 22 Period 2: 22 Period 3: 16 Period 4: 21
#                                      0
# 1    [0.226, 0.03, 0.222, 0.212, 0.28]
# 2  [0.376, 0.113, 0.126, 0.248, 0.093]
# 3      [0.361, 0.0, 0.0, 0.365, 0.389]
# 4   [0.139, 0.209, 0.122, 0.335, 0.12]
# Player Name: Josh Huestis
# Shots Taken Period 1: 35 Period 2: 48 Period 3: 40 Period 4: 59
#                                      0
# 1  [0.083, 0.657, 0.214, 0.303, 0.098]
# 2    [0.162, 0.716, 0.119, 0.287, 0.0]
# 3     [0.06, 0.778, 0.119, 0.178, 0.0]
# 4    [0.049, 0.964, 0.082, 0.166, 0.0]
# Player Name: Jamil Wilson
# Shots Taken Period 1: 21 Period 2: 11 Period 3: 32 Period 4: 17
#                                    0
# 1   [0.201, 0.83, 0.092, 0.003, 0.0]
# 2     [0.0, 0.979, 0.0, 0.036, 0.15]
# 3  [0.008, 0.829, 0.052, 0.0, 0.066]
# 4  [0.027, 0.893, 0.016, 0.0, 0.037]
# Player Name: Kristaps Porzingis
# Shots Taken Period 1: 291 Period 2: 195 Period 3: 199 Period 4: 191
#                                      0
# 1  [0.127, 0.247, 0.083, 0.068, 0.019]
# 2  [0.142, 0.267, 0.054, 0.092, 0.046]
# 3     [0.1, 0.334, 0.047, 0.083, 0.03]
# 4  [0.165, 0.212, 0.075, 0.083, 0.011]
# Player Name: Jack Cooley
# Shots Taken Period 1: 7 Period 2: 8 Period 3: 3 Period 4: 9
#                                    0
# 1    [0.231, 0.0, 0.508, 0.305, 0.0]
# 2  [0.365, 0.0, 0.167, 0.202, 0.135]
# 3    [0.563, 0.0, 1.029, 0.345, 0.0]
# 4    [0.471, 0.0, 0.131, 0.0, 0.042]
# Player Name: Tarik Black
# Shots Taken Period 1: 32 Period 2: 20 Period 3: 22 Period 4: 50
#                                     0
# 1    [0.89, 0.0, 0.228, 0.312, 0.171]
# 2   [0.706, 0.0, 0.129, 0.164, 0.259]
# 3   [0.548, 0.0, 0.273, 0.419, 0.012]
# 4  [0.465, 0.062, 0.123, 0.518, 0.11]
# Player Name: Travis Wear
# Shots Taken Period 1: 5 Period 2: 36 Period 3: 6 Period 4: 25
#                                    0
# 1    [0.0, 0.713, 0.004, 0.0, 0.003]
# 2  [0.058, 0.831, 0.0, 0.002, 0.001]
# 3        [0.0, 1.001, 0.0, 0.0, 0.0]
# 4     [0.004, 0.61, 0.011, 0.0, 0.0]
# Player Name: Omari Johnson
# Shots Taken Period 1: 4 Period 2: 8 Period 3: 7 Period 4: 2
#                                  0
# 1   [0.24, 0.0, 0.164, 0.596, 0.0]
# 2  [0.218, 0.521, 0.0, 0.161, 0.0]
# 3    [0.0, 0.571, 0.0, 0.189, 0.0]
# 4    [0.0, 0.973, 0.0, 0.0, 0.006]
# Player Name: Andrew Harrison
# Shots Taken Period 1: 94 Period 2: 102 Period 3: 131 Period 4: 102
#                                      0
# 1   [0.233, 0.377, 0.153, 0.19, 0.058]
# 2    [0.2, 0.316, 0.124, 0.143, 0.088]
# 3  [0.323, 0.314, 0.187, 0.165, 0.031]
# 4  [0.166, 0.395, 0.086, 0.178, 0.113]
# Player Name: Aaron Harrison
# Shots Taken Period 1: 10 Period 2: 23 Period 3: 16 Period 4: 18
#                                      0
# 1    [0.261, 0.645, 0.067, 0.037, 0.0]
# 2  [0.058, 0.633, 0.021, 0.032, 0.008]
# 3      [0.122, 0.625, 0.241, 0.0, 0.0]
# 4  [0.095, 0.674, 0.133, 0.083, 0.033]
# Player Name: Cameron Payne
# Shots Taken Period 1: 54 Period 2: 53 Period 3: 55 Period 4: 53
#                                      0
# 1  [0.124, 0.324, 0.122, 0.129, 0.104]
# 2  [0.126, 0.464, 0.076, 0.138, 0.028]
# 3   [0.182, 0.451, 0.061, 0.084, 0.09]
# 4  [0.123, 0.435, 0.063, 0.073, 0.108]
# Player Name: Jordan Mickey
# Shots Taken Period 1: 14 Period 2: 26 Period 3: 15 Period 4: 27
#                                      0
# 1  [0.628, 0.111, 0.121, 0.125, 0.244]
# 2   [0.648, 0.219, 0.149, 0.131, 0.12]
# 3    [0.633, 0.0, 0.349, 0.205, 0.173]
# 4  [0.157, 0.252, 0.323, 0.069, 0.192]
# Player Name: Dakari Johnson
# Shots Taken Period 1: 14 Period 2: 4 Period 3: 6 Period 4: 15
#                                   0
# 1   [0.537, 0.0, 0.306, 0.355, 0.0]
# 2  [0.606, 0.0, 0.315, 0.162, 0.41]
# 3       [0.823, 0.0, 0.0, 0.0, 0.0]
# 4    [0.48, 0.0, 0.0, 0.233, 0.208]
# Player Name: Joe Young
# Shots Taken Period 1: 23 Period 2: 61 Period 3: 22 Period 4: 80
#                                      0
# 1     [0.065, 0.449, 0.0, 0.076, 0.08]
# 2      [0.3, 0.317, 0.072, 0.084, 0.0]
# 3     [0.206, 0.291, 0.0, 0.024, 0.09]
# 4  [0.307, 0.274, 0.134, 0.131, 0.028]
# Player Name: Malcolm Delaney
# Shots Taken Period 1: 56 Period 2: 92 Period 3: 65 Period 4: 72
#                                     0
# 1  [0.138, 0.488, 0.051, 0.01, 0.062]
# 2  [0.208, 0.465, 0.103, 0.017, 0.04]
# 3   [0.257, 0.59, 0.018, 0.05, 0.047]
# 4  [0.162, 0.526, 0.01, 0.111, 0.082]
# Player Name: Briante Weber
# Shots Taken Period 1: 6 Period 2: 13 Period 3: 12 Period 4: 12
#                                      0
# 1     [0.15, 0.361, 0.0, 0.074, 0.205]
# 2     [0.396, 0.158, 0.053, 0.0, 0.01]
# 3  [0.009, 0.125, 0.465, 0.032, 0.459]
# 4    [0.366, 0.449, 0.0, 0.014, 0.074]
# Player Name: Wade Baldwin IV
# Shots Taken Period 1: 2 Period 2: 9 Period 3: 2 Period 4: 8
#                                      0
# 1      [0.047, 0.169, 0.004, 0.0, 0.0]
# 2  [0.128, 0.336, 0.217, 0.178, 0.187]
# 3        [0.013, 0.775, 0.0, 0.0, 0.0]
# 4  [0.056, 0.142, 0.116, 0.239, 0.212]
# Player Name: Brice Johnson
# Shots Taken Period 1: 2 Period 2: 7 Period 3: 7 Period 4: 26
#                                      0
# 1        [0.0, 0.188, 0.0, 0.0, 0.024]
# 2  [0.023, 0.065, 0.024, 0.172, 0.144]
# 3    [0.578, 0.0, 0.284, 0.011, 0.085]
# 4     [0.525, 0.0, 0.241, 0.051, 0.02]
# Player Name: Dejounte Murray
# Shots Taken Period 1: 140 Period 2: 144 Period 3: 154 Period 4: 169
#                                      0
# 1  [0.154, 0.104, 0.096, 0.239, 0.132]
# 2  [0.194, 0.088, 0.138, 0.234, 0.091]
# 3     [0.311, 0.0, 0.255, 0.22, 0.095]
# 4  [0.251, 0.061, 0.197, 0.188, 0.168]
# Player Name: Tyler Ulis
# Shots Taken Period 1: 149 Period 2: 134 Period 3: 142 Period 4: 126
#                                      0
# 1   [0.067, 0.35, 0.014, 0.034, 0.094]
# 2  [0.163, 0.329, 0.025, 0.038, 0.058]
# 3  [0.151, 0.299, 0.027, 0.027, 0.138]
# 4   [0.108, 0.337, 0.024, 0.029, 0.06]
# Player Name: Denzel Valentine
# Shots Taken Period 1: 167 Period 2: 198 Period 3: 173 Period 4: 180
#                                      0
# 1   [0.098, 0.546, 0.04, 0.031, 0.057]
# 2  [0.064, 0.595, 0.051, 0.019, 0.097]
# 3   [0.069, 0.64, 0.085, 0.035, 0.061]
# 4  [0.096, 0.561, 0.047, 0.039, 0.095]
# Player Name: Ron Baker
# Shots Taken Period 1: 7 Period 2: 22 Period 3: 10 Period 4: 20
#                                      0
# 1      [0.343, 0.573, 0.0, 0.0, 0.042]
# 2  [0.167, 0.603, 0.206, 0.162, 0.051]
# 3     [0.116, 1.029, 0.0, 0.12, 0.082]
# 4  [0.339, 0.338, 0.228, 0.033, 0.126]
# Player Name: Kay Felder
# Shots Taken Period 1: 6 Period 2: 23 Period 3: 9 Period 4: 32
#                                      0
# 1     [0.0, 0.333, 0.31, 0.179, 0.114]
# 2  [0.132, 0.322, 0.016, 0.067, 0.067]
# 3  [0.244, 0.116, 0.334, 0.039, 0.093]
# 4     [0.078, 0.354, 0.14, 0.0, 0.055]
# Player Name: Gary Payton II
# Shots Taken Period 1: 21 Period 2: 17 Period 3: 11 Period 4: 25
#                                      0
# 1   [0.392, 0.725, 0.092, 0.325, 0.05]
# 2  [0.154, 0.309, 0.525, 0.205, 0.201]
# 3  [0.267, 0.047, 0.531, 0.382, 0.087]
# 4  [0.066, 0.592, 0.174, 0.082, 0.056]
# Player Name: Malachi Richardson
# Shots Taken Period 1: 15 Period 2: 26 Period 3: 14 Period 4: 35
#                                    0
# 1     [0.21, 0.492, 0.0, 0.0, 0.103]
# 2   [0.424, 0.44, 0.0, 0.031, 0.065]
# 3    [0.115, 1.167, 0.034, 0.0, 0.0]
# 4  [0.307, 0.367, 0.0, 0.082, 0.209]
# Player Name: Isaiah Whitehead
# Shots Taken Period 1: 12 Period 2: 15 Period 3: 17 Period 4: 42
#                                      0
# 1      [0.354, 0.1, 0.322, 0.227, 0.0]
# 2    [0.0, 0.244, 0.221, 0.247, 0.213]
# 3   [0.17, 0.062, 0.325, 0.046, 0.261]
# 4  [0.131, 0.276, 0.075, 0.158, 0.196]
# Player Name: Isaiah Taylor
# Shots Taken Period 1: 92 Period 2: 95 Period 3: 69 Period 4: 134
#                                      0
# 1     [0.295, 0.276, 0.21, 0.068, 0.0]
# 2  [0.454, 0.204, 0.189, 0.031, 0.076]
# 3    [0.571, 0.075, 0.313, 0.114, 0.0]
# 4  [0.545, 0.098, 0.228, 0.183, 0.025]
# Player Name: James Webb III
# Shots Taken Period 1: 2 Period 2: 6 Period 3: 3 Period 4: 13
#                                    0
# 1        [0.0, 2.713, 0.0, 0.0, 0.0]
# 2      [0.0, 1.445, 0.0, 0.003, 0.0]
# 3  [0.313, 1.323, 0.0, 0.253, 0.193]
# 4  [0.147, 1.012, 0.0, 0.121, 0.089]
# Player Name: Georgios Papagiannis
# Shots Taken Period 1: 5 Period 2: 10 Period 3: 3 Period 4: 24
#                                     0
# 1   [0.028, 0.033, 0.0, 0.294, 0.292]
# 2     [0.0, 0.0, 0.014, 0.754, 0.087]
# 3       [0.702, 0.0, 0.0, 0.133, 0.0]
# 4  [0.19, 0.042, 0.001, 0.305, 0.049]
# Player Name: Paul Zipser
# Shots Taken Period 1: 33 Period 2: 87 Period 3: 36 Period 4: 78
#                                      0
# 1    [0.131, 0.391, 0.107, 0.0, 0.077]
# 2  [0.044, 0.583, 0.046, 0.086, 0.044]
# 3  [0.165, 0.476, 0.042, 0.044, 0.073]
# 4  [0.179, 0.599, 0.026, 0.085, 0.066]
# Player Name: Kyle Collinsworth
# Shots Taken Period 1: 17 Period 2: 21 Period 3: 16 Period 4: 44
#                                      0
# 1  [0.286, 0.081, 0.192, 0.257, 0.027]
# 2     [0.597, 0.262, 0.12, 0.012, 0.0]
# 3   [0.364, 0.199, 0.043, 0.126, 0.01]
# 4   [0.397, 0.179, 0.28, 0.167, 0.022]
# Player Name: Marcus Georges-Hunt
# Shots Taken Period 1: 3 Period 2: 12 Period 3: 6 Period 4: 27
#                                      0
# 1        [0.0, 0.931, 0.0, 0.0, 0.006]
# 2    [0.232, 0.164, 0.529, 0.452, 0.0]
# 3     [0.531, 0.171, 0.0, 0.229, 0.16]
# 4  [0.245, 0.383, 0.161, 0.016, 0.239]
# Player Name: Jalen Jones
# Shots Taken Period 1: 11 Period 2: 12 Period 3: 12 Period 4: 32
#                                      0
# 1  [0.248, 0.391, 0.035, 0.099, 0.081]
# 2     [0.368, 0.24, 0.285, 0.278, 0.0]
# 3    [0.0, 0.126, 0.146, 0.464, 0.317]
# 4   [0.239, 0.435, 0.211, 0.147, 0.09]
# Player Name: Josh Gray
# Shots Taken Period 1: 10 Period 2: 9 Period 3: 4 Period 4: 18
#                                      0
# 1  [0.111, 0.408, 0.135, 0.207, 0.173]
# 2      [0.382, 0.0, 0.383, 0.075, 0.0]
# 3    [0.386, 0.392, 0.334, 0.007, 0.0]
# 4  [0.239, 0.241, 0.075, 0.401, 0.074]
# Player Name: Myke Henry
# Shots Taken Period 1: 18 Period 2: 26 Period 3: 34 Period 4: 31
#                                      0
# 1      [0.3, 0.367, 0.0, 0.437, 0.323]
# 2  [0.008, 0.727, 0.153, 0.158, 0.107]
# 3  [0.086, 0.426, 0.273, 0.074, 0.144]
# 4   [0.012, 0.628, 0.028, 0.196, 0.03]
# Player Name: Alec Peters
# Shots Taken Period 1: 6 Period 2: 9 Period 3: 14 Period 4: 45
#                                      0
# 1    [0.024, 0.884, 0.234, 0.122, 0.0]
# 2      [0.112, 0.921, 0.0, 0.15, 0.12]
# 3        [0.0, 0.897, 0.007, 0.0, 0.0]
# 4  [0.113, 0.878, 0.046, 0.115, 0.035]
# Player Name: Kobi Simmons
# Shots Taken Period 1: 50 Period 2: 43 Period 3: 44 Period 4: 52
#                                      0
# 1   [0.222, 0.203, 0.243, 0.23, 0.006]
# 2  [0.164, 0.097, 0.317, 0.173, 0.117]
# 3  [0.239, 0.241, 0.145, 0.189, 0.077]
# 4  [0.096, 0.284, 0.172, 0.114, 0.029]
# Player Name: Jabari Bird
# Shots Taken Period 1: 3 Period 2: 12 Period 3: 3 Period 4: 8
#                                     0
# 1         [0.0, 1.521, 0.0, 0.0, 0.0]
# 2      [0.169, 0.0, 0.0, 0.985, 0.28]
# 3        [0.0, 0.0, 0.0, 0.17, 0.987]
# 4  [0.119, 0.424, 0.183, 0.26, 0.104]
# Player Name: Mike James
# Shots Taken Period 1: 69 Period 2: 74 Period 3: 73 Period 4: 105
#                                      0
# 1  [0.182, 0.327, 0.089, 0.094, 0.118]
# 2  [0.166, 0.317, 0.056, 0.057, 0.126]
# 3    [0.279, 0.318, 0.08, 0.07, 0.118]
# 4  [0.293, 0.243, 0.111, 0.049, 0.167]
# Player Name: Milos Teodosic
# Shots Taken Period 1: 100 Period 2: 107 Period 3: 81 Period 4: 72
#                                      0
# 1  [0.091, 0.602, 0.031, 0.015, 0.031]
# 2   [0.026, 0.771, 0.04, 0.007, 0.031]
# 3   [0.058, 0.657, 0.013, 0.021, 0.01]
# 4  [0.047, 0.754, 0.025, 0.026, 0.059]
# Player Name: Derrick Walton Jr.
# Shots Taken Period 1: 3 Period 2: 12 Period 3: 3 Period 4: 7
#                                    0
# 1        [0.0, 1.054, 0.0, 0.0, 0.0]
# 2      [0.0, 0.782, 0.0, 0.0, 0.002]
# 3        [0.0, 1.284, 0.0, 0.0, 0.0]
# 4  [0.001, 0.254, 0.007, 0.0, 0.011]
# Player Name: Milton Doyle
# Shots Taken Period 1: 2 Period 2: 8 Period 3: 3 Period 4: 34
#                                     0
# 1          [0.0, 0.0, 0.94, 0.0, 0.0]
# 2   [0.0, 0.466, 0.073, 0.195, 0.329]
# 3     [0.0, 0.639, 0.004, 0.0, 0.013]
# 4  [0.095, 0.467, 0.139, 0.011, 0.11]
# Player Name: Nigel Hayes
# Shots Taken Period 1: 9 Period 2: 5 Period 3: 11 Period 4: 8
#                                     0
# 1     [0.161, 0.694, 0.067, 0.0, 0.0]
# 2     [0.014, 0.732, 0.003, 0.0, 0.0]
# 3   [0.083, 0.799, 0.0, 0.067, 0.062]
# 4  [0.311, 1.31, 0.031, 0.071, 0.083]
# Player Name: Jamel Artis
# Shots Taken Period 1: 10 Period 2: 18 Period 3: 16 Period 4: 35
#                                      0
# 1     [0.007, 0.946, 0.001, 0.0, 0.02]
# 2    [0.221, 0.636, 0.045, 0.0, 0.015]
# 3  [0.049, 0.253, 0.334, 0.116, 0.082]
# 4     [0.132, 0.28, 0.103, 0.0, 0.106]
# Player Name: Xavier Rathan-Mayes
# Shots Taken Period 1: 8 Period 2: 8 Period 3: 8 Period 4: 18
#                                    0
# 1       [0.003, 0.75, 0.0, 0.0, 0.0]
# 2  [0.032, 0.315, 0.0, 0.098, 0.145]
# 3    [0.0, 0.311, 0.238, 0.177, 0.0]
# 4   [0.0, 0.376, 0.008, 0.052, 0.35]
# Player Name: Andrew White III
# Shots Taken Period 1: 14 Period 2: 21 Period 3: 15 Period 4: 23
#                                    0
# 1  [0.123, 0.792, 0.0, 0.028, 0.079]
# 2  [0.149, 0.696, 0.058, 0.0, 0.073]
# 3    [0.0, 0.812, 0.021, 0.084, 0.0]
# 4  [0.061, 0.982, 0.066, 0.058, 0.0]
# Player Name: Jaylen Morris
# Shots Taken Period 1: 5 Period 2: 7 Period 3: 12 Period 4: 8
#                                     0
# 1    [0.467, 0.0, 0.037, 0.216, 0.54]
# 2      [0.395, 0.38, 0.0, 0.007, 0.0]
# 3  [0.371, 0.363, 0.03, 0.152, 0.339]
# 4   [0.731, 0.239, 0.0, 0.172, 0.316]
# Player Name: Rodney Purvis
# Shots Taken Period 1: 12 Period 2: 39 Period 3: 13 Period 4: 43
#                                     0
# 1     [0.231, 0.748, 0.0, 0.0, 0.163]
# 2     [0.053, 0.624, 0.072, 0.0, 0.0]
# 3       [0.054, 0.791, 0.0, 0.0, 0.0]
# 4  [0.18, 0.506, 0.047, 0.092, 0.016]

# %%
print(type(H[:,9]))
# Out:
# <class 'numpy.ndarray'>
